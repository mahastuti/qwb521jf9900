# %%
import pandas as pd

# %%
data = pd.read_excel("bird.xlsx", sheet_name="bird-species")

# %%
data["jenis_burung"].unique()
df_jenis = pd.DataFrame(data["jenis_burung"].unique(), columns=["jenis_burung"])

# %%
df_jenis = pd.DataFrame(data["jenis_burung"].unique(), columns=["jenis_burung"])
map_nama = data.set_index("jenis_burung")["nama_ilmiah"].to_dict()
df_jenis["nama_ilmiah"] = df_jenis["jenis_burung"].map(map_nama)
df_jenis
# Out:
#                jenis_burung                 nama_ilmiah
# 0              Blekok Sawah            Ardeola speciosa
# 1             Bondol Peking         Lonchura punctulata
# 2                Cangak Abu               Ardea cinerea
# 3              Cangak Merah              Ardea purpurea
# 4              Kokokan Laut          Butorides striatus
# 5              Kuntul Kecil            Egretta garzetta
# 6        Layang-Layang Batu            Hirundo javanica
# 7              Walet Linchi           Collocalia linchi
# 8           Dara Laut Biasa              Sterna hirundo
# 9             Kedidi Golgol         Calidris ferruginea
# 10             Kuntul Perak          Egretta intermedia
# 11         Pecuk Padi Kecil            Microcarbo niger
# 12                 Perkutut            Geopelia striata
# 13            Burung Gereja             Passer montanus
# 14         Pecuk Padi Hitam  Phalacrocorax sulcirostris
# 15               Bubut Jawa        Centropus nigrorufus
# ...

# %%
df_jenis.to_excel("jenis_burung.xlsx", index=False)
df_jenis
# Out:
#                jenis_burung                 nama_ilmiah
# 0              Blekok Sawah            Ardeola speciosa
# 1             Bondol Peking         Lonchura punctulata
# 2                Cangak Abu               Ardea cinerea
# 3              Cangak Merah              Ardea purpurea
# 4              Kokokan Laut          Butorides striatus
# 5              Kuntul Kecil            Egretta garzetta
# 6        Layang-Layang Batu            Hirundo javanica
# 7              Walet Linchi           Collocalia linchi
# 8           Dara Laut Biasa              Sterna hirundo
# 9             Kedidi Golgol         Calidris ferruginea
# 10             Kuntul Perak          Egretta intermedia
# 11         Pecuk Padi Kecil            Microcarbo niger
# 12                 Perkutut            Geopelia striata
# 13            Burung Gereja             Passer montanus
# 14         Pecuk Padi Hitam  Phalacrocorax sulcirostris
# 15               Bubut Jawa        Centropus nigrorufus
# ...
